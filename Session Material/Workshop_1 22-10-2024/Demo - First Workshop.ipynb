# %% [markdown]
# # Function Definition

# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# ## Getting Data

# %%
def get_data(ticker, start_date, end_date):
    data = yf.download(ticker, start_date, end_date)
    return data


def plot_symbol(symbol, start, end, color='black'):
    ticker = get_data(symbol, start, end)
    name = yf.Ticker(symbol).info['shortName']
    plt.figure(figsize=(7,4))
    plt.plot(ticker['Adj Close'], color=color, linewidth=0.7)
    plt.xlabel("Date")
    plt.ylabel(f"{name} Price")
    plt.title(f"{name} Over Time")
    plt.show()

# %% [markdown]
# ## Plotting
# Plotting a given function against market data

# %%
def plot_against_market(t, x = lambda t: np.exp(growthRate*t)):
    plt.figure(figsize=(7,4))
    plt.plot(t, get_data("^GSPC", '2000-01-28', '2024-01-26')['Adj Close'], color='r', linewidth=0.7)
    plt.plot(t, x, color='green', linewidth=0.7)
    plt.show()

# %% [markdown]
# # Plot Maret Data

# %%
plot_symbol("^GSPC", '2000-01-28', '2024-01-26', 'r')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Function Evolution

# %% [markdown]
# ## Variable Definition

# %%
growthRate = 0.08
pi = np.pi

t = np.linspace(1, 100, 6036)

# %% [markdown]
# ## Step 1

# %%
x = np.exp(growthRate*t)

plot_against_market(t, x)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## Step 2

# %%
x = np.exp(growthRate*t) + 5*np.sin(2*pi*1*t)

plot_against_market(t, x)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## Step 3

# %%
x = np.exp(growthRate*t) + 0.4*np.exp(growthRate*t)*(np.sin(2*pi*0.25*t))

plot_against_market(t, x)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## Step 4

# %%
x = 1000 + np.exp(growthRate*t)*(1 + 0.1*np.sin(2*pi*1*t) + 0.2*np.sin(2*pi*0.25*t) + 0.08*np.sin(2*pi*0.35*t))

plot_against_market(t, x)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Plot Market Cycles

# %%
t = np.linspace(1, 100, 6036)
t = t[0:int(len(t)/4)]
plt.figure(figsize=(7,4))
plt.plot(t, 0.1*np.sin(2*pi*1*t) + 0.2*np.sin(2*pi*0.25*t) + 0.08*np.sin(2*pi*0.35*t), linewidth=0.7)
plt.title("Market Cycles")
plt.show()
